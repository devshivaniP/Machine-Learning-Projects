# %% [markdown]
# # Importing the Required Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing the Dataset

# %%
data = pd.read_csv("Documents/DS Projects/creditcard.csv")
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# # Data Preprocessing

# %%
#checking for the null values
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# There are no null values

# %%
#checking for duplicate values
data.duplicated().sum()
# Out:
# 1081

# %%
#removing the duplicate values
data.drop_duplicates(inplace = True)
data.duplicated().sum()
# Out:
# 0

# %%
#Analysing the distribution of Fraud and Valid Transcations
data['Class'].value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %%
plt.pie(data['Class'].value_counts(), labels = data['Class'].value_counts().index,autopct='%1.2f%%')
plt.title("Distribution of Transcations")
plt.show()

# %%
fraud = data[data['Class'] == 1]
valid = data[data['Class'] == 0]

# %%
print(len(fraud))
# Out:
# 473

# %%
fraud.Amount.describe()
# Out:
# count     473.000000
# mean      123.871860
# std       260.211041
# min         0.000000
# 25%         1.000000
# 50%         9.820000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
valid.Amount.describe()
# Out:
# count    283253.000000
# mean         88.413575
# std         250.379023
# min           0.000000
# 25%           5.670000
# 50%          22.000000
# 75%          77.460000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
print("Fraud Cases: {}".format(len(fraud)))
print("Valid Cases: {}".format(len(valid)))
# Out:
# Fraud Cases: 473
# Valid Cases: 283253

# %%
outlier_fraction = len(fraud)/len(valid)
print(outlier_fraction)
# Out:
# 0.0016698852262818046

# %%
#Draw distribution plot for Time and Amount
fig, ax=plt.subplots(2,1, figsize=(16,8))
sns.histplot(data.Amount,bins=100, color='r', ax=ax[0]);
ax[0].set_title("Distribution plot of Amount Column")
sns.histplot(data.Time,bins=50, color='b',ax=ax[1]);
ax[1].set_title("Distribution plot of Time Column");

# %%
data.hist(figsize = (20, 20))
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.scatter(data.Time[data.Class==0],data.Amount[data.Class==0], color=["green"])

plt.title("Transaction Amount of each Valid Transactions over Time")
plt.xlabel("Time")
plt.ylabel("Amount")
plt.legend(["Valid Transactions"])

# %%
plt.figure(figsize=(6,5))
plt.scatter(data.Time[data.Class==1],data.Amount[data.Class==1], color=["red"])
plt.title("Transaction Amount of each Fraud Transactions over Time")
plt.xlabel("Time")
plt.ylabel("Amount")
plt.legend(["Fraudulent Transactions"]);

# %%
correlation_matrix = data.corr()
fig = plt.figure(figsize = (5,4))
sns.heatmap(correlation_matrix, vmax = .8, annot = False, square = True)
plt.show()

# %% [markdown]
#  The mean of fraud transactions is comparatively high and if can lead to the overfitting of the model. Let's transform the data

# %% [markdown]
# # Splitting the data

# %%
X= data.drop(['Class'],axis=1)
Y=data['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, train_size = 0.8, random_state = 42)
Y_train.value_counts()
# Out:
# 0    226597
# 1       383
# Name: Class, dtype: int64

# %%
#Using SMOTE 
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state = 0)
X_train, Y_train = smote.fit_resample(X_train, Y_train)
X_test, Y_test = smote.fit_resample(X_test, Y_test)
Y_train.value_counts()
# Out:
# 0    226597
# 1    226597
# Name: Class, dtype: int64

# %% [markdown]
# # Model Training and Evaluation

# %% [markdown]
#  Algorithms like Random Forest Classifier and KNN are time consuming.
#  Using pycaret, we can evaluate and compare all the models simultaneously and can train model on the algorithm with the highest accuracy.

# %%
from pycaret.classification import *
clf = setup(data = data, target = 'Class')
best=compare_models()
best
# Out:
# <style type="text/css">
# #T_25e0d_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_25e0d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25e0d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_25e0d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25e0d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_25e0d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_25e0d_row0_col1" class="data row0 col1" >5398</td>
#     </tr>
#     <tr>
#       <th id="T_25e0d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_25e0d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_25e0d_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_25e0d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# ##### In the terms of accuracy, precision and F1 score, Random Forest Classifier is performing best among all. But this algorithm is very time consuming to apply on this data. Thus, we will be using a time efficient algorithm like Logistic Regression, which also provides acceptable accuracy, as compared to RFC.

# %%
from sklearn.linear_model import LogisticRegression
LR_Model = LogisticRegression()
LR_Model.fit(X_train, Y_train)
Y_pred_LR = LR_Model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, precision_recall_curve, classification_report, precision_score, recall_score, accuracy_score
cnf_matrix = confusion_matrix(Y_test, Y_pred_LR)
accuracy_LR = accuracy_score(Y_test, Y_pred_LR)
print("Accuracy of the model is", accuracy_LR*100)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')

labels = ['Non-fraud', 'Fraud']
print(classification_report(Y_test, Y_pred_LR, target_names=labels))
# Out:
# Accuracy of the model is 96.55464558034453
#               precision    recall  f1-score   support
#
#    Non-fraud       0.95      0.98      0.97     56656
#        Fraud       0.98      0.95      0.97     56656
#
#     accuracy                           0.97    113312
#    macro avg       0.97      0.97      0.97    113312
# weighted avg       0.97      0.97      0.97    113312

# %%
#Performing cross validation
from sklearn.model_selection import GridSearchCV
grid={"C":np.logspace(-3,3,7), "penalty":["l2"]}  # l2 ridge

clf_lsr_cv = GridSearchCV(LR_Model,grid,cv=3,scoring='roc_auc')
clf_lsr_cv.fit(X_train,Y_train)

print("tuned hpyerparameters :(best parameters)",clf_lsr_cv.best_params_)
print("accuracy :",clf_lsr_cv.best_score_)
# Out:
# tuned hpyerparameters :(best parameters) {'C': 10.0, 'penalty': 'l2'}
# accuracy : 0.9934437876349476

# %%
#Using the best parameters
lsr_best = LogisticRegression(penalty='l2',C=10.0,random_state = 42)
lsr_clf = lsr_best.fit(X_train,Y_train)
Y_pred_best_LR = LR_Model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, precision_recall_curve, classification_report, precision_score, recall_score, accuracy_score
cnf_matrix = confusion_matrix(Y_test, Y_pred_best_LR)
accuracy_LR = accuracy_score(Y_test, Y_pred_best_LR)
print("Accuracy of the model is", accuracy_LR*100)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')

labels = ['Non-fraud', 'Fraud']
print(classification_report(Y_test, Y_pred_best_LR, target_names=labels))
# Out:
# Accuracy of the model is 96.55464558034453
#               precision    recall  f1-score   support
#
#    Non-fraud       0.95      0.98      0.97     56656
#        Fraud       0.98      0.95      0.97     56656
#
#     accuracy                           0.97    113312
#    macro avg       0.97      0.97      0.97    113312
# weighted avg       0.97      0.97      0.97    113312
